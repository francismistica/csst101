# %%
# Rule based: Computer Troubleshooting Assistant
# Author: Francis Mistica
# Description: Provides solution on common PC problems.

cat("💻 Welcome to your Computer Troubleshooting Assistant! \n")
cat("Let's figure out what is wrong with your computer.\n\n")

cat("Please select the issues you are encountering: \n")
cat("1 - Computer won't start\n")
cat("2 - Slow performance\n")
cat("3 - No internet connection\n")
cat("4 - Blue screen or system crash\n")
cat("5 - Overheating\n")
cat("6 - Unresponsive programs\n\n")

cat("Enter the number of your issue: ")

choice <- as.integer(readline())

cat("\n------------------------------------------------------------\n")

if(choice == 1) {
  cat("🪫 Possible causes:\n")
  cat("- Power supply issue\n- Faulty cables or outlet\n- Battery or adapter problem (for laptops)\n")
  cat("\n💡 Recommended actions:\n")
  cat("- Check if the power cable is securely plugged in.\n- Try a different power outlet.\n- Remove the battery and connect the charger only.\n")
} else if (choice == 2) {
  cat("🐢 Possible causes:\n")
  cat("- Too many background apps\n- Low memory or storage\n- Malware or startup programs\n")
  cat("\n💡 Recommended actions:\n")
  cat("- Close unnecessary apps.\n- Run a virus scan.\n- Clear temporary files and free up disk space.\n")
} else if (choice == 3) {
  cat("🌐 Possible causes:\n")
  cat("- Wi-Fi is turned off\n- Router or ISP issue\n- Incorrect network settings\n")
  cat("\n💡 Recommended actions:\n")
  cat("- Restart your router.\n- Check Wi-Fi settings.\n- Contact your Internet Service Provider if the problem persists.\n")
} else if (choice == 4) {
  cat("💥 Possible causes:\n")
  cat("- Driver or hardware failure\n- Corrupted system files\n- Overheating or faulty RAM\n")
  cat("\n💡 Recommended actions:\n")
  cat("- Boot into Safe Mode.\n- Update or reinstall drivers.\n- Check hardware connections.\n")
} else if (choice == 5) {
  cat("🔥 Possible causes:\n")
  cat("- Blocked air vents\n- High CPU usage\n- Faulty cooling fan\n")
  cat("\n💡 Recommended actions:\n")
  cat("- Clean dust from vents and fans.\n- Use your laptop on a hard, flat surface.\n- Check CPU temperature using monitoring software.\n")
} else if (choice == 6) {
  cat("⚠️ Possible causes:\n")
  cat("- Too many open applications\n- Software bugs or insufficient memory\n")
  cat("\n💡 Recommended actions:\n")
  cat("- Use Task Manager to close unresponsive programs.\n- Restart your computer.\n- Reinstall or update the problematic software.\n")
} else {
    cat("X Invalid please try again!")
}

cat("\n------------------------------------------------------------\n")
cat("🧩 End of troubleshooting session.")
# Out:
# 💻 Welcome to your Computer Troubleshooting Assistant!
# Let's figure out what is wrong with your computer.
#
# Please select the issues you are encountering:
# 1 - Computer won't start
# 2 - Slow performance
# 3 - No internet connection
# 4 - Blue screen or system crash
# 5 - Overheating
# 6 - Unresponsive programs
#
# Enter the number of your issue: 3
#
# ------------------------------------------------------------
# 🌐 Possible causes:
# - Wi-Fi is turned off
# - Router or ISP issue
# - Incorrect network settings
#
# 💡 Recommended actions:
# - Restart your router.
# - Check Wi-Fi settings.
# - Contact your Internet Service Provider if the problem persists.
#
# ------------------------------------------------------------
# 🧩 End of troubleshooting session.
